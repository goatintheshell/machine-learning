# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd

# %%
exam_data = pd.read_csv('exams.csv', quotechar='"')
exam_data
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group C            some high school  free/reduced
# 1   female        group C                some college      standard
# 2     male        group B                 high school      standard
# 3     male        group E           bachelor's degree  free/reduced
# 4   female        group B                 high school      standard
# ..     ...            ...                         ...           ...
# 95  female        group C                some college      standard
# 96  female        group C                 high school  free/reduced
# 97    male        group C                some college      standard
# 98  female        group C             master's degree      standard
# 99  female        group B                 high school      standard
#
#    test preparation course  math score  reading score  writing score
# 0                completed          54             72             71
# 1                     none          66             80             77
# 2                     none          71             64             61
# 3                     none          94             89             85
# 4                     none          73             82             74
# ..                     ...         ...            ...            ...
# 95                    none          90             95             91
# 96                    none          47             61             54
# 97                    none          66             68             65
# 98                    none          64             84             75
# 99                    none          39             59             54
#
# [100 rows x 8 columns]

# %%
from sklearn import preprocessing

exam_data[['math score']] = preprocessing.scale(exam_data[['math score']])
exam_data[['reading score']] = preprocessing.scale(exam_data[['reading score']])
exam_data[['writing score']] = preprocessing.scale(exam_data[['writing score']])

# %%
exam_data
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group C            some high school  free/reduced
# 1   female        group C                some college      standard
# 2     male        group B                 high school      standard
# 3     male        group E           bachelor's degree  free/reduced
# 4   female        group B                 high school      standard
# ..     ...            ...                         ...           ...
# 95  female        group C                some college      standard
# 96  female        group C                 high school  free/reduced
# 97    male        group C                some college      standard
# 98  female        group C             master's degree      standard
# 99  female        group B                 high school      standard
#
#    test preparation course  math score  reading score  writing score
# 0                completed   -0.748215       0.096066       0.164977
# 1                     none   -0.025302       0.601677       0.539926
# 2                     none    0.275912      -0.409545      -0.459937
# 3                     none    1.661495       1.170490       1.039857
# 4                     none    0.396397       0.728080       0.352452
# ..                     ...         ...            ...            ...
# 95                    none    1.420524       1.549698       1.414805
# 96                    none   -1.169914      -0.599149      -0.897377
# 97                    none   -0.025302      -0.156739      -0.209971
# 98                    none   -0.145787       0.854483       0.414943
# 99                    none   -1.651856      -0.725552      -0.897377
#
# [100 rows x 8 columns]

# %%
math_average = exam_data['math score'].mean()
reading_average = exam_data['reading score'].mean()
writing_average = exam_data['writing score'].mean()

print('Math average: ', math_average)
print('Reading average: ', reading_average)
print('Writing average: ', writing_average)
# Out:
# Math average:  -8.881784197001253e-18
# Reading average:  -2.4202861936828414e-16
# Writing average:  4.9960036108132046e-17

# %%
le = preprocessing.LabelEncoder()
exam_data['gender'] = le.fit_transform(exam_data['gender'].astype(str))
exam_data
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0        0        group C            some high school  free/reduced
# 1        0        group C                some college      standard
# 2        1        group B                 high school      standard
# 3        1        group E           bachelor's degree  free/reduced
# 4        0        group B                 high school      standard
# ..     ...            ...                         ...           ...
# 95       0        group C                some college      standard
# 96       0        group C                 high school  free/reduced
# 97       1        group C                some college      standard
# 98       0        group C             master's degree      standard
# 99       0        group B                 high school      standard
#
#    test preparation course  math score  reading score  writing score
# 0                completed   -0.748215       0.096066       0.164977
# 1                     none   -0.025302       0.601677       0.539926
# 2                     none    0.275912      -0.409545      -0.459937
# 3                     none    1.661495       1.170490       1.039857
# 4                     none    0.396397       0.728080       0.352452
# ..                     ...         ...            ...            ...
# 95                    none    1.420524       1.549698       1.414805
# 96                    none   -1.169914      -0.599149      -0.897377
# 97                    none   -0.025302      -0.156739      -0.209971
# 98                    none   -0.145787       0.854483       0.414943
# 99                    none   -1.651856      -0.725552      -0.897377
#
# [100 rows x 8 columns]

# %%
le.classes_
# Out:
# array(['0', '1'], dtype=object)

# %%
exam_data = pd.get_dummies(exam_data, columns=['race/ethnicity'])
exam_data.head()
# Out:
#    gender parental level of education         lunch test preparation course  \
# 0       0            some high school  free/reduced               completed
# 1       0                some college      standard                    none
# 2       1                 high school      standard                    none
# 3       1           bachelor's degree  free/reduced                    none
# 4       0                 high school      standard                    none
#
#    math score  reading score  writing score  race/ethnicity_group A  \
# 0   -0.748215       0.096066       0.164977                   False
# 1   -0.025302       0.601677       0.539926                   False
# 2    0.275912      -0.409545      -0.459937                   False
# 3    1.661495       1.170490       1.039857                   False
# 4    0.396397       0.728080       0.352452                   False
#
#    race/ethnicity_group B  race/ethnicity_group C  race/ethnicity_group D  \
# 0                   False                    True                   False
# 1                   False                    True                   False
# 2                    True                   False                   False
# 3                   False                   False                   False
# 4                    True                   False                   False
#
#    race/ethnicity_group E
# 0                   False
# 1                   False
# 2                   False
# 3                    True
# 4                   False

# %%
exam_data = pd.get_dummies(exam_data)
exam_data.head()
# Out:
#    gender  math score  reading score  writing score  race/ethnicity_group A  \
# 0       0   -0.748215       0.096066       0.164977                   False
# 1       0   -0.025302       0.601677       0.539926                   False
# 2       1    0.275912      -0.409545      -0.459937                   False
# 3       1    1.661495       1.170490       1.039857                   False
# 4       0    0.396397       0.728080       0.352452                   False
#
#    race/ethnicity_group B  race/ethnicity_group C  race/ethnicity_group D  \
# 0                   False                    True                   False
# 1                   False                    True                   False
# 2                    True                   False                   False
# 3                   False                   False                   False
# 4                    True                   False                   False
#
#    race/ethnicity_group E  parental level of education_associate's degree  \
# 0                   False                                           False
# 1                   False                                           False
# 2                   False                                           False
# 3                    True                                           False
# 4                   False                                           False
#
#    parental level of education_bachelor's degree  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                           True
# 4                                          False
#
#    parental level of education_high school  \
# 0                                    False
# 1                                    False
# 2                                     True
# 3                                    False
# 4                                     True
#
#    parental level of education_master's degree  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
#
#    parental level of education_some college  \
# 0                                     False
# 1                                      True
# 2                                     False
# 3                                     False
# 4                                     False
#
#    parental level of education_some high school  lunch_free/reduced  \
# 0                                          True                True
# 1                                         False               False
# 2                                         False               False
# 3                                         False                True
# 4                                         False               False
#
#    lunch_standard  test preparation course_completed  \
# 0           False                               True
# 1            True                              False
# 2            True                              False
# 3           False                              False
# 4            True                              False
#
#    test preparation course_none
# 0                         False
# 1                          True
# 2                          True
# 3                          True
# 4                          True
